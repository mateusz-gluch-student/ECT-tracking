# %%
from ect.tracking import NaiveMatcher, FFTTransformer
from ect.helpers import SingleImageGenerator

from matplotlib import pyplot as plt

# %%
SOURCE_IMAGE = '/home/mateusz/Desktop/Magisterka/tracking/images/tracker_tests/1_template.png'

gen = SingleImageGenerator(SOURCE_IMAGE, logpolar=False)
tr = FFTTransformer()

plt.imshow(gen.generate())

match = NaiveMatcher((325, 190), (120, 120), tr)

# %%
tpl = match.initialize(gen.generate())

plt.imshow(tpl)
